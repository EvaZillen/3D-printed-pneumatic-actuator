# %% [markdown]
# # Import

# %% [markdown]
# #### Libraries

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

diametercilinder=25
r=diametercilinder/2/1000
Area= math.pi*r**2

diametercilindergroot=25.7
rgroot=diametercilindergroot/2/1000
Areagroot= math.pi*rgroot**2

drop_amount=15 #Eerste 15 datapunten verwijderen, om gekke opstartwaardes te verwijderen.

# %% [markdown]
# #### Data import dynamic leakage tests

# %%
#25mm
#o-ring
O_dynleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 10 25 49 T2_O_dyn.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_dynleakage.drop(columns=['A','B','C'],index=O_dynleakage.index[range(drop_amount)],axis=1,inplace=True)
#NAPN
NAPN_dynleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 11 05 38 T2_NAPN_dyn.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAPN_dynleakage.drop(columns=['A','B','C'],index=NAPN_dynleakage.index[range(drop_amount)],axis=1,inplace=True)
#310
NAP310_dynleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 12 05 04 T2_310_dyn.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAP310_dynleakage.drop(columns=['A','B','C'],index=NAP310_dynleakage.index[range(drop_amount)],axis=1,inplace=True)
#PK
PK_dynleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 12 27 30 T2_PK_dyn.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
PK_dynleakage.drop(columns=['A','B','C'],index=PK_dynleakage.index[range(drop_amount)],axis=1,inplace=True)
#KDN
KDN_dynleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 12 52 52 T2_KDN_dyn.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
KDN_dynleakage.drop(columns=['A','B','C'],index=KDN_dynleakage.index[range(drop_amount)],axis=1,inplace=True)

TO_dynleakage = O_dynleakage['Time']
LO_dynleakage = O_dynleakage['Laser(mm)']
PO_dynleakage = O_dynleakage['Pressure(bar)']
FO_dynleakage = O_dynleakage['Force(N)']

TNAPN_dynleakage = NAPN_dynleakage['Time']
LNAPN_dynleakage = NAPN_dynleakage['Laser(mm)']
PNAPN_dynleakage = NAPN_dynleakage['Pressure(bar)']
FNAPN_dynleakage = NAPN_dynleakage['Force(N)']

TNAP310_dynleakage = NAP310_dynleakage['Time']
LNAP310_dynleakage = NAP310_dynleakage['Laser(mm)']
PNAP310_dynleakage = NAP310_dynleakage['Pressure(bar)']
FNAP310_dynleakage = NAP310_dynleakage['Force(N)']

TPK_dynleakage = PK_dynleakage['Time']
LPK_dynleakage = PK_dynleakage['Laser(mm)']
PPK_dynleakage = PK_dynleakage['Pressure(bar)']
FPK_dynleakage = PK_dynleakage['Force(N)']

TKDN_dynleakage = KDN_dynleakage['Time']
LKDN_dynleakage = KDN_dynleakage['Laser(mm)']
PKDN_dynleakage = KDN_dynleakage['Pressure(bar)']
FKDN_dynleakage = KDN_dynleakage['Force(N)']

#25.7mm
#O-ring
O_257_dynleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 11 11 17 09 T2_25.7mm_O_dyn.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_257_dynleakage.drop(columns=['A','B','C'],index=O_257_dynleakage.index[range(drop_amount)],axis=1,inplace=True)
#X-ring
X_257_dynleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 11 09 54 36 T2_25.7mm_X_dyn.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
X_257_dynleakage.drop(columns=['A','B','C'],index=X_257_dynleakage.index[range(drop_amount)],axis=1,inplace=True)

TO_257_dynleakage = O_257_dynleakage['Time']
LO_257_dynleakage = O_257_dynleakage['Laser(mm)']
PO_257_dynleakage = O_257_dynleakage['Pressure(bar)']
FO_257_dynleakage = O_257_dynleakage['Force(N)']

TX_257_dynleakage = X_257_dynleakage['Time']
LX_257_dynleakage = X_257_dynleakage['Laser(mm)']
PX_257_dynleakage = X_257_dynleakage['Pressure(bar)']
FX_257_dynleakage = X_257_dynleakage['Force(N)']

# %% [markdown]
# #### Data import static leakage test

# %%
#o-ring
O_statleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 13 31 47 T2_O_stat.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_statleakage.drop(columns=['A','B','C'],index=O_statleakage.index[range(drop_amount)],axis=1,inplace=True)
#NAPN
NAPN_statleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 13 59 08 T2_NAPN_stat.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAPN_statleakage.drop(columns=['A','B','C'],index=NAPN_statleakage.index[range(drop_amount)],axis=1,inplace=True)
#310
NAP310_statleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 14 25 31 T2_310_stat.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAP310_statleakage.drop(columns=['A','B','C'],index=NAP310_statleakage.index[range(drop_amount)],axis=1,inplace=True)
#PK
PK_statleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 14 59 36 T2_PK_stat.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
PK_statleakage.drop(columns=['A','B','C'],index=PK_statleakage.index[range(drop_amount)],axis=1,inplace=True)
#KDN
KDN_statleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 10 16 14 30 T2_KDN_stat.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
KDN_statleakage.drop(columns=['A','B','C'],index=KDN_statleakage.index[range(drop_amount)],axis=1,inplace=True)

TO_statleakage = O_statleakage['Time']/1000
LO_statleakage = O_statleakage['Laser(mm)']
PO_statleakage = O_statleakage['Pressure(bar)']
FO_statleakage = O_statleakage['Force(N)']

TNAPN_statleakage = NAPN_statleakage['Time']/1000
LNAPN_statleakage = NAPN_statleakage['Laser(mm)']
PNAPN_statleakage = NAPN_statleakage['Pressure(bar)']
FNAPN_statleakage = NAPN_statleakage['Force(N)']

TNAP310_statleakage = NAP310_statleakage['Time']/1000
LNAP310_statleakage = NAP310_statleakage['Laser(mm)']
PNAP310_statleakage = NAP310_statleakage['Pressure(bar)']
FNAP310_statleakage = NAP310_statleakage['Force(N)']

TPK_statleakage = PK_statleakage['Time']/1000
LPK_statleakage = PK_statleakage['Laser(mm)']
PPK_statleakage = PK_statleakage['Pressure(bar)']
FPK_statleakage = PK_statleakage['Force(N)']

TKDN_statleakage = KDN_statleakage['Time']/1000
LKDN_statleakage = KDN_statleakage['Laser(mm)']
PKDN_statleakage = KDN_statleakage['Pressure(bar)']
FKDN_statleakage = KDN_statleakage['Force(N)']

#25.7mm
#O-ring
O_257_statleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 11 11 41 37 T2_25.7mm_O_stat.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_257_statleakage.drop(columns=['A','B','C'],index=O_257_statleakage.index[range(drop_amount)],axis=1,inplace=True)
#X-ring
X_257_statleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 11 10 33 13 T2_25.7mm_X_stat.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
X_257_statleakage.drop(columns=['A','B','C'],index=X_257_statleakage.index[range(drop_amount)],axis=1,inplace=True)

TO_257_statleakage = O_257_statleakage['Time']/1000
LO_257_statleakage = O_257_statleakage['Laser(mm)']
PO_257_statleakage = O_257_statleakage['Pressure(bar)']
FO_257_statleakage = O_257_statleakage['Force(N)']

TX_257_statleakage = X_257_statleakage['Time']/1000
LX_257_statleakage = X_257_statleakage['Laser(mm)']
PX_257_statleakage = X_257_statleakage['Pressure(bar)']
FX_257_statleakage = X_257_statleakage['Force(N)']

# %% [markdown]
# #### Data import friction test

# %%
# 25mm
#1 bar
#o-ring
O_1bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 13 35 31 T3_25mm_O_1bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_1bar.drop(columns=['A','B','C'],index=O_1bar.index[range(drop_amount)],axis=1,inplace=True)
#NAPN
NAPN_1bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 13 40 28 T3_25mm_NAPN_1bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAPN_1bar.drop(columns=['A','B','C'],index=NAPN_1bar.index[range(drop_amount)],axis=1,inplace=True)
#310
NAP310_1bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 13 43 01 T3_25mm_310_1bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAP310_1bar.drop(columns=['A','B','C'],index=NAP310_1bar.index[range(drop_amount)],axis=1,inplace=True)
#PK
PK_1bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 13 49 13 T3_25mm_PK_1bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
PK_1bar.drop(columns=['A','B','C'],index=PK_1bar.index[range(drop_amount)],axis=1,inplace=True)
#KDN
KDN_1bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 13 53 47 T3_25mm_KDN_1bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
KDN_1bar.drop(columns=['A','B','C'],index=KDN_1bar.index[range(drop_amount)],axis=1,inplace=True)

#3 bar
#o-ring
O_3bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 14 14 53 T3_25mm_O_3bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_3bar.drop(columns=['A','B','C'],index=O_3bar.index[range(drop_amount)],axis=1,inplace=True)
#NAPN
NAPN_3bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 14 19 56 T3_25mm_NAPN_3bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAPN_3bar.drop(columns=['A','B','C'],index=NAPN_3bar.index[range(drop_amount)],axis=1,inplace=True)
#310
NAP310_3bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 14 24 24 T3_25mm_310_3bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAP310_3bar.drop(columns=['A','B','C'],index=NAP310_3bar.index[range(drop_amount)],axis=1,inplace=True)
#PK
PK_3bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 14 30 30 T3_25mm_PK_3bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
PK_3bar.drop(columns=['A','B','C'],index=PK_3bar.index[range(drop_amount)],axis=1,inplace=True)
#KDN
KDN_3bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 14 35 28 T3_25mm_KDN_3bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
KDN_3bar.drop(columns=['A','B','C'],index=KDN_3bar.index[range(drop_amount)],axis=1,inplace=True)


# 5 bar
#o-ring
O_5bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 14 50 41 T3_25mm_O_5bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_5bar.drop(columns=['A','B','C'],index=O_5bar.index[range(drop_amount)],axis=1,inplace=True)
#NAPN
NAPN_5bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 14 57 24 T3_25mm_NAPN_5bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAPN_5bar.drop(columns=['A','B','C'],index=NAPN_5bar.index[range(drop_amount)],axis=1,inplace=True)
#310
NAP310_5bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 15 01 04 T3_25mm_310_5bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAP310_5bar.drop(columns=['A','B','C'],index=NAP310_5bar.index[range(drop_amount)],axis=1,inplace=True)
#PK
PK_5bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 15 06 08 T3_25mm_PK_5bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
PK_5bar.drop(columns=['A','B','C'],index=PK_5bar.index[range(drop_amount)],axis=1,inplace=True)
#KDN
KDN_5bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 09 15 10 05 T3_25mm_KDN_5bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
KDN_5bar.drop(columns=['A','B','C'],index=KDN_5bar.index[range(drop_amount)],axis=1,inplace=True)

# 7 bar
#o-ring
O_7bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 10 17 27 38 T3_25mm_O_7bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_7bar.drop(columns=['A','B','C'],index=O_7bar.index[range(drop_amount)],axis=1,inplace=True)
#NAPN
NAPN_7bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 10 17 29 26 T3_25mm_NAPN_7bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAPN_7bar.drop(columns=['A','B','C'],index=NAPN_7bar.index[range(drop_amount)],axis=1,inplace=True)
#310
NAP310_7bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 10 17 34 15 T3_25mm_NAP310_7bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
NAP310_7bar.drop(columns=['A','B','C'],index=NAP310_7bar.index[range(drop_amount)],axis=1,inplace=True)
#PK
PK_7bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 10 17 36 48 T3_25mm_PK_7bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
PK_7bar.drop(columns=['A','B','C'],index=PK_7bar.index[range(drop_amount)],axis=1,inplace=True)
#KDN
KDN_7bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 10 17 39 09 T3_25mm_KDN_7bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
KDN_7bar.drop(columns=['A','B','C'],index=KDN_7bar.index[range(drop_amount)],axis=1,inplace=True)


# 1 bar
TO_1bar = O_1bar['Time']
LO_1bar = O_1bar['Laser(mm)']
PO_1bar = O_1bar['Pressure(bar)']
FO_1bar = O_1bar['Force(N)']
TNAPN_1bar = NAPN_1bar['Time']
LNAPN_1bar = NAPN_1bar['Laser(mm)']
PNAPN_1bar = NAPN_1bar['Pressure(bar)']
FNAPN_1bar = NAPN_1bar['Force(N)']
TNAP310_1bar = NAP310_1bar['Time']
LNAP310_1bar = NAP310_1bar['Laser(mm)']
PNAP310_1bar = NAP310_1bar['Pressure(bar)']
FNAP310_1bar = NAP310_1bar['Force(N)']
TPK_1bar = PK_1bar['Time']
LPK_1bar = PK_1bar['Laser(mm)']
PPK_1bar = PK_1bar['Pressure(bar)']
FPK_1bar = PK_1bar['Force(N)']
TKDN_1bar = KDN_1bar['Time']
LKDN_1bar = KDN_1bar['Laser(mm)']
PKDN_1bar = KDN_1bar['Pressure(bar)']
FKDN_1bar = KDN_1bar['Force(N)']


# 3 bar
TO_3bar = O_3bar['Time']
LO_3bar = O_3bar['Laser(mm)']
PO_3bar = O_3bar['Pressure(bar)']
FO_3bar = O_3bar['Force(N)']
TNAPN_3bar = NAPN_3bar['Time']
LNAPN_3bar = NAPN_3bar['Laser(mm)']
PNAPN_3bar = NAPN_3bar['Pressure(bar)']
FNAPN_3bar = NAPN_3bar['Force(N)']
TNAP310_3bar = NAP310_3bar['Time']
LNAP310_3bar = NAP310_3bar['Laser(mm)']
PNAP310_3bar = NAP310_3bar['Pressure(bar)']
FNAP310_3bar = NAP310_3bar['Force(N)']
TPK_3bar = PK_3bar['Time']
LPK_3bar = PK_3bar['Laser(mm)']
PPK_3bar = PK_3bar['Pressure(bar)']
FPK_3bar = PK_3bar['Force(N)']
TKDN_3bar = KDN_3bar['Time']
LKDN_3bar = KDN_3bar['Laser(mm)']
PKDN_3bar = KDN_3bar['Pressure(bar)']
FKDN_3bar = KDN_3bar['Force(N)']

# 5 bar
TO_5bar = O_5bar['Time']
LO_5bar = O_5bar['Laser(mm)']
PO_5bar = O_5bar['Pressure(bar)']
FO_5bar = O_5bar['Force(N)']
TNAPN_5bar = NAPN_5bar['Time']
LNAPN_5bar = NAPN_5bar['Laser(mm)']
PNAPN_5bar = NAPN_5bar['Pressure(bar)']
FNAPN_5bar = NAPN_5bar['Force(N)']
TNAP310_5bar = NAP310_5bar['Time']
LNAP310_5bar = NAP310_5bar['Laser(mm)']
PNAP310_5bar = NAP310_5bar['Pressure(bar)']
FNAP310_5bar = NAP310_5bar['Force(N)']
TPK_5bar = PK_5bar['Time']
LPK_5bar = PK_5bar['Laser(mm)']
PPK_5bar = PK_5bar['Pressure(bar)']
FPK_5bar = PK_5bar['Force(N)']
TKDN_5bar = KDN_5bar['Time']
LKDN_5bar = KDN_5bar['Laser(mm)']
PKDN_5bar = KDN_5bar['Pressure(bar)']
FKDN_5bar = KDN_5bar['Force(N)']

# 7 bar
TO_7bar = O_7bar['Time']
LO_7bar = O_7bar['Laser(mm)']
PO_7bar = O_7bar['Pressure(bar)']
FO_7bar = O_7bar['Force(N)']
TNAPN_7bar = NAPN_7bar['Time']
LNAPN_7bar = NAPN_7bar['Laser(mm)']
PNAPN_7bar = NAPN_7bar['Pressure(bar)']
FNAPN_7bar = NAPN_7bar['Force(N)']
TNAP310_7bar = NAP310_7bar['Time']
LNAP310_7bar = NAP310_7bar['Laser(mm)']
PNAP310_7bar = NAP310_7bar['Pressure(bar)']
FNAP310_7bar = NAP310_7bar['Force(N)']
TPK_7bar = PK_7bar['Time']
LPK_7bar = PK_7bar['Laser(mm)']
PPK_7bar = PK_7bar['Pressure(bar)']
FPK_7bar = PK_7bar['Force(N)']
TKDN_7bar = KDN_7bar['Time']
LKDN_7bar = KDN_7bar['Laser(mm)']
PKDN_7bar = KDN_7bar['Pressure(bar)']
FKDN_7bar = KDN_7bar['Force(N)']

O_257_1bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 11 01 30 T3_25.7mm_O_1bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_257_1bar.drop(columns=['A','B','C'],index=O_257_1bar.index[range(drop_amount)],axis=1,inplace=True)
X_257_1bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 09 29 50 T3_25.7mm_X_1bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
X_257_1bar.drop(columns=['A','B','C'],index=X_257_1bar.index[range(drop_amount)],axis=1,inplace=True)
O_257_3bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 11 04 08 T3_25.7mm_O_3bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_257_3bar.drop(columns=['A','B','C'],index=O_257_3bar.index[range(drop_amount)],axis=1,inplace=True)
X_257_3bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 09 36 05 T3_25.7mm_X_3bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
X_257_3bar.drop(columns=['A','B','C'],index=X_257_3bar.index[range(drop_amount)],axis=1,inplace=True)
O_257_5bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 11 07 49 T3_25.7mm_O_5bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_257_5bar.drop(columns=['A','B','C'],index=O_257_5bar.index[range(drop_amount)],axis=1,inplace=True)
X_257_5bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 09 41 31 T3_25.7mm_X_5bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
X_257_5bar.drop(columns=['A','B','C'],index=X_257_5bar.index[range(drop_amount)],axis=1,inplace=True)
O_257_7bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 11 12 00 T3_25.7mm_O_7bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
O_257_7bar.drop(columns=['A','B','C'],index=O_257_7bar.index[range(drop_amount)],axis=1,inplace=True)
X_257_7bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 09 46 05 T3_25.7mm_X_7bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
X_257_7bar.drop(columns=['A','B','C'],index=X_257_7bar.index[range(drop_amount)],axis=1,inplace=True)

#1bar
TO_257_1bar = O_257_1bar['Time']
LO_257_1bar = O_257_1bar['Laser(mm)']
PO_257_1bar = O_257_1bar['Pressure(bar)']
FO_257_1bar = O_257_1bar['Force(N)']
TX_257_1bar = X_257_1bar['Time']
LX_257_1bar = X_257_1bar['Laser(mm)']
PX_257_1bar = X_257_1bar['Pressure(bar)']
FX_257_1bar = X_257_1bar['Force(N)']

#3bar
TO_257_3bar = O_257_3bar['Time']
LO_257_3bar = O_257_3bar['Laser(mm)']
PO_257_3bar = O_257_3bar['Pressure(bar)']
FO_257_3bar = O_257_3bar['Force(N)']
TX_257_3bar = X_257_3bar['Time']
LX_257_3bar = X_257_3bar['Laser(mm)']
PX_257_3bar = X_257_3bar['Pressure(bar)']
FX_257_3bar = X_257_3bar['Force(N)']

#5bar
TO_257_5bar = O_257_5bar['Time']
LO_257_5bar = O_257_5bar['Laser(mm)']
PO_257_5bar = O_257_5bar['Pressure(bar)']
FO_257_5bar = O_257_5bar['Force(N)']
TX_257_5bar = X_257_5bar['Time']
LX_257_5bar = X_257_5bar['Laser(mm)']
PX_257_5bar = X_257_5bar['Pressure(bar)']
FX_257_5bar = X_257_5bar['Force(N)']

#7bar
TO_257_7bar = O_257_7bar['Time']
LO_257_7bar = O_257_7bar['Laser(mm)']
PO_257_7bar = O_257_7bar['Pressure(bar)']
FO_257_7bar = O_257_7bar['Force(N)']
TX_257_7bar = X_257_7bar['Time']
LX_257_7bar = X_257_7bar['Laser(mm)']
PX_257_7bar = X_257_7bar['Pressure(bar)']
FX_257_7bar = X_257_7bar['Force(N)']

# %%
#ovaal
ovaal_dynleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 11 14 05 08 T2_ovaal_dyn.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
ovaal_dynleakage.drop(columns=['A','B','C'],index=ovaal_dynleakage.index[range(drop_amount)],axis=1,inplace=True)
Tovaal_dynleakage = ovaal_dynleakage['Time']
Lovaal_dynleakage = ovaal_dynleakage['Laser(mm)']
Povaal_dynleakage = ovaal_dynleakage['Pressure(bar)']
Fovaal_dynleakage = ovaal_dynleakage['Force(N)']
# ovaal_dynleakage_30 = ovaal_dynleakage[(ovaal_dynleakage['Laser(mm)'] > (value_ovaal-speling)) & (ovaal_dynleakage['Laser(mm)'] < (value_ovaal+speling))]
# Tovaal_dynleakage_30=ovaal_dynleakage_30['Time']/1000
# Povaal_dynleakage_30=ovaal_dynleakage_30['Pressure(bar)']
# Lovaal_dynleakage_30=ovaal_dynleakage_30['Laser(mm)']

ovaal_statleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 11 14 31 41 T2_ovaal_stat.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
ovaal_statleakage.drop(columns=['A','B','C'],index=ovaal_statleakage.index[range(drop_amount)],axis=1,inplace=True)
Tovaal_statleakage = ovaal_statleakage['Time']/1000
Lovaal_statleakage = ovaal_statleakage['Laser(mm)']
Povaal_statleakage = ovaal_statleakage['Pressure(bar)']
Fovaal_statleakage = ovaal_statleakage['Force(N)']

ovaal_1bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 13 37 52 T3_ovaal_1bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
ovaal_1bar.drop(columns=['A','B','C'],index=ovaal_1bar.index[range(drop_amount)],axis=1,inplace=True)
ovaal_2bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 13 47 55 T3_ovaal_2bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
ovaal_2bar.drop(columns=['A','B','C'],index=ovaal_2bar.index[range(drop_amount)],axis=1,inplace=True)
ovaal_3bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 13 43 12 T3_ovaal_3bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
ovaal_3bar.drop(columns=['A','B','C'],index=ovaal_3bar.index[range(drop_amount)],axis=1,inplace=True)
Tovaal_1bar = ovaal_1bar['Time']
Lovaal_1bar = ovaal_1bar['Laser(mm)']
Povaal_1bar = ovaal_1bar['Pressure(bar)']
Fovaal_1bar = ovaal_1bar['Force(N)']
Tovaal_2bar = ovaal_2bar['Time']
Lovaal_2bar = ovaal_2bar['Laser(mm)']
Povaal_2bar = ovaal_2bar['Pressure(bar)']
Fovaal_2bar = ovaal_2bar['Force(N)']
Tovaal_3bar = ovaal_3bar['Time']
Lovaal_3bar = ovaal_3bar['Laser(mm)']
Povaal_3bar = ovaal_3bar['Pressure(bar)']
Fovaal_3bar = ovaal_3bar['Force(N)']
Ft_ovaal_1bar=Povaal_1bar*10**5*Area
FF_ovaal_1bar = Fovaal_1bar - Ft_ovaal_1bar
x_ovaal_1bar = np.arange(0,len(Lovaal_1bar)/100,0.01)
Ft_ovaal_2bar=Povaal_2bar*10**5*Area
FF_ovaal_2bar = Fovaal_2bar - Ft_ovaal_2bar
x_ovaal_2bar = np.arange(0,len(Lovaal_2bar)/100,0.01)
Ft_ovaal_3bar=Povaal_3bar*10**5*Area
FF_ovaal_3bar = Fovaal_3bar - Ft_ovaal_3bar
x_ovaal_3bar = np.arange(0,len(Lovaal_3bar)/100,0.01)
frictieheenweg_ovaal_1 = FF_ovaal_1bar[FF_ovaal_1bar>0].mean()
frictieterugweg_ovaal_1 = FF_ovaal_1bar[FF_ovaal_1bar<0].mean()
frictierange_ovaal_1 = frictieheenweg_ovaal_1 - frictieterugweg_ovaal_1
frictieheenweg_ovaal_2 = FF_ovaal_2bar[FF_ovaal_2bar>0].mean()
frictieterugweg_ovaal_2 = FF_ovaal_2bar[FF_ovaal_2bar<0].mean()
frictierange_ovaal_2 = frictieheenweg_ovaal_2 - frictieterugweg_ovaal_2
frictieheenweg_ovaal_3 = FF_ovaal_3bar[FF_ovaal_3bar>0].mean()
frictieterugweg_ovaal_3 = FF_ovaal_3bar[FF_ovaal_3bar<0].mean()
frictierange_ovaal_3 = frictieheenweg_ovaal_3 - frictieterugweg_ovaal_3

#kidney
kidney_dynleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 11 16 02 02 T2_kidney_dyn.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
kidney_dynleakage.drop(columns=['A','B','C'],index=kidney_dynleakage.index[range(drop_amount)],axis=1,inplace=True)
Tkidney_dynleakage = kidney_dynleakage['Time']
Lkidney_dynleakage = kidney_dynleakage['Laser(mm)']
Pkidney_dynleakage = kidney_dynleakage['Pressure(bar)']
Fkidney_dynleakage = kidney_dynleakage['Force(N)']

# kidney_dynleakage_30 = kidney_dynleakage[(kidney_dynleakage['Laser(mm)'] > (value_kidney-speling)) & (kidney_dynleakage['Laser(mm)'] < (value_kidney+speling))]
# Tkidney_dynleakage_30=kidney_dynleakage_30['Time']/1000
# Pkidney_dynleakage_30=kidney_dynleakage_30['Pressure(bar)']
# Lkidney_dynleakage_30=kidney_dynleakage_30['Laser(mm)']

kidney_statleakage = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test2_lekcilinder/21 06 11 16 27 26 T2_kidney_stat.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
kidney_statleakage.drop(columns=['A','B','C'],index=kidney_statleakage.index[range(drop_amount)],axis=1,inplace=True)
Tkidney_statleakage = kidney_statleakage['Time']/1000
Lkidney_statleakage = kidney_statleakage['Laser(mm)']
Pkidney_statleakage = kidney_statleakage['Pressure(bar)']
Fkidney_statleakage = kidney_statleakage['Force(N)']

kidney_1bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 15 39 04 T2_kidney_1bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
kidney_1bar.drop(columns=['A','B','C'],index=kidney_1bar.index[range(drop_amount)],axis=1,inplace=True)
kidney_2bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 15 44 25 T2_kidney_2bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
kidney_2bar.drop(columns=['A','B','C'],index=kidney_2bar.index[range(drop_amount)],axis=1,inplace=True)
kidney_3bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 15 49 23 T2_kidney_3bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
kidney_3bar.drop(columns=['A','B','C'],index=kidney_3bar.index[range(drop_amount)],axis=1,inplace=True)
kidney_4bar = pd.read_csv (r'/Users/evazillen/Documents/Studie/Afstuderen/Thesis/1_Tests/Test3_frictie/21 06 11 15 58 38 T2_kidney_4bar.csv',delimiter='\s+',header=None,names=(['Time','A','B','C','Laser(mm)','Pressure(bar)','Force(N)']))
kidney_4bar.drop(columns=['A','B','C'],index=kidney_4bar.index[range(drop_amount)],axis=1,inplace=True)
Tkidney_1bar = kidney_1bar['Time']
Lkidney_1bar = kidney_1bar['Laser(mm)']
Pkidney_1bar = kidney_1bar['Pressure(bar)']
Fkidney_1bar = kidney_1bar['Force(N)']
Tkidney_2bar = kidney_2bar['Time']
Lkidney_2bar = kidney_2bar['Laser(mm)']
Pkidney_2bar = kidney_2bar['Pressure(bar)']
Fkidney_2bar = kidney_2bar['Force(N)']
Tkidney_3bar = kidney_3bar['Time']
Lkidney_3bar = kidney_3bar['Laser(mm)']
Pkidney_3bar = kidney_3bar['Pressure(bar)']
Fkidney_3bar = kidney_3bar['Force(N)']
Tkidney_4bar = kidney_4bar['Time']
Lkidney_4bar = kidney_4bar['Laser(mm)']
Pkidney_4bar = kidney_4bar['Pressure(bar)']
Fkidney_4bar = kidney_4bar['Force(N)']
Ft_kidney_1bar=Pkidney_1bar*10**5*Area
FF_kidney_1bar = Fkidney_1bar - Ft_kidney_1bar
x_kidney_1bar = np.arange(0,len(Lkidney_1bar)/100,0.01)
Ft_kidney_2bar=Pkidney_2bar*10**5*Area
FF_kidney_2bar = Fkidney_2bar - Ft_kidney_2bar
x_kidney_2bar = np.arange(0,len(Lkidney_2bar)/100,0.01)
Ft_kidney_3bar=Pkidney_3bar*10**5*Area
FF_kidney_3bar = Fkidney_3bar - Ft_kidney_3bar
x_kidney_3bar = np.arange(0,len(Lkidney_3bar)/100,0.01)
Ft_kidney_4bar=Pkidney_4bar*10**5*Area
FF_kidney_4bar = Fkidney_4bar - Ft_kidney_4bar
x_kidney_4bar = np.arange(0,len(Lkidney_4bar)/100,0.01)
frictieheenweg_kidney_1 = FF_kidney_1bar[FF_kidney_1bar>0].mean()
frictieterugweg_kidney_1 = FF_kidney_1bar[FF_kidney_1bar<0].mean()
frictierange_kidney_1 = frictieheenweg_kidney_1 - frictieterugweg_kidney_1
frictieheenweg_kidney_2 = FF_kidney_2bar[FF_kidney_2bar>0].mean()
frictieterugweg_kidney_2 = FF_kidney_2bar[FF_kidney_2bar<0].mean()
frictierange_kidney_2 = frictieheenweg_kidney_2 - frictieterugweg_kidney_2
frictieheenweg_kidney_3 = FF_kidney_3bar[FF_kidney_3bar>0].mean()
frictieterugweg_kidney_3 = FF_kidney_3bar[FF_kidney_3bar<0].mean()
frictierange_kidney_3 = frictieheenweg_kidney_3 - frictieterugweg_kidney_3
frictieheenweg_kidney_4 = FF_kidney_4bar[FF_kidney_4bar>0].mean()
frictieterugweg_kidney_4 = FF_kidney_4bar[FF_kidney_4bar<0].mean()
frictierange_kidney_4 = frictieheenweg_kidney_4 - frictieterugweg_kidney_3

# %% [markdown]
# # Test 2: Leakage test

# %% [markdown]
# #### Dynamic leakage

# %%
value_O=37.7
value_NAPN=38
value_NAP310=37.7
value_PK=37.8
value_KDN=37.7

value_O_257 = 37.7
value_X_257 = 37.7

# value_O=36.9
# value_O_257=37
value_ovaal=38.5
value_kidney=39.3

speling = 0.02

# %%
#25mm
O_dynleakage_30 = O_dynleakage[(O_dynleakage['Laser(mm)'] > (value_O-speling)) & (O_dynleakage['Laser(mm)'] < (value_O+speling))]
O_dynleakage_30
TO_dynleakage_30=O_dynleakage_30['Time']/1000
PO_dynleakage_30=O_dynleakage_30['Pressure(bar)']
LO_dynleakage_30=O_dynleakage_30['Laser(mm)']

NAPN_dynleakage_30 = NAPN_dynleakage[(NAPN_dynleakage['Laser(mm)'] > (value_NAPN-speling)) & (NAPN_dynleakage['Laser(mm)'] < (value_NAPN+speling))]
NAPN_dynleakage_30
TNAPN_dynleakage_30=NAPN_dynleakage_30['Time']/1000
PNAPN_dynleakage_30=NAPN_dynleakage_30['Pressure(bar)']
LNAPN_dynleakage_30=NAPN_dynleakage_30['Laser(mm)']

NAP310_dynleakage_30 = NAP310_dynleakage[(NAP310_dynleakage['Laser(mm)'] > (value_NAP310-speling)) & (NAP310_dynleakage['Laser(mm)'] < (value_NAP310+speling))]
NAP310_dynleakage_30
TNAP310_dynleakage_30=NAP310_dynleakage_30['Time']/1000
PNAP310_dynleakage_30=NAP310_dynleakage_30['Pressure(bar)']
LNAP310_dynleakage_30=NAP310_dynleakage_30['Laser(mm)']

PK_dynleakage_30 = PK_dynleakage[(PK_dynleakage['Laser(mm)'] > (value_PK-speling)) & (PK_dynleakage['Laser(mm)'] < (value_PK+speling))]
PK_dynleakage_30
TPK_dynleakage_30=PK_dynleakage_30['Time']/1000
PPK_dynleakage_30=PK_dynleakage_30['Pressure(bar)']
LPK_dynleakage_30=PK_dynleakage_30['Laser(mm)']

KDN_dynleakage_30 = KDN_dynleakage[(KDN_dynleakage['Laser(mm)'] > (value_KDN-speling)) & (KDN_dynleakage['Laser(mm)'] < (value_KDN+speling))]
KDN_dynleakage_30
TKDN_dynleakage_30=KDN_dynleakage_30['Time']/1000
PKDN_dynleakage_30=KDN_dynleakage_30['Pressure(bar)']
LKDN_dynleakage_30=KDN_dynleakage_30['Laser(mm)']

#25.7 mm
O_257_dynleakage_30 = O_257_dynleakage[(O_257_dynleakage['Laser(mm)'] > (value_O_257-speling)) & (O_257_dynleakage['Laser(mm)'] < (value_O_257+speling))]
O_257_dynleakage_30
TO_257_dynleakage_30=O_257_dynleakage_30['Time']/1000
PO_257_dynleakage_30=O_257_dynleakage_30['Pressure(bar)']
LO_257_dynleakage_30=O_257_dynleakage_30['Laser(mm)']

X_257_dynleakage_30 = X_257_dynleakage[(X_257_dynleakage['Laser(mm)'] > (value_X_257-speling)) & (X_257_dynleakage['Laser(mm)'] < (value_X_257+speling))]
X_257_dynleakage_30
TX_257_dynleakage_30=X_257_dynleakage_30['Time']/1000
PX_257_dynleakage_30=X_257_dynleakage_30['Pressure(bar)']
LX_257_dynleakage_30=X_257_dynleakage_30['Laser(mm)']

#shapes
ovaal_dynleakage_30 = ovaal_dynleakage[(ovaal_dynleakage['Laser(mm)'] > (value_ovaal-speling)) & (ovaal_dynleakage['Laser(mm)'] < (value_ovaal+speling))]
Tovaal_dynleakage_30=ovaal_dynleakage_30['Time']/1000
Povaal_dynleakage_30=ovaal_dynleakage_30['Pressure(bar)']
Lovaal_dynleakage_30=ovaal_dynleakage_30['Laser(mm)']

kidney_dynleakage_30 = kidney_dynleakage[(kidney_dynleakage['Laser(mm)'] > (value_kidney-speling)) & (kidney_dynleakage['Laser(mm)'] < (value_kidney+speling))]
Tkidney_dynleakage_30=kidney_dynleakage_30['Time']/1000
Pkidney_dynleakage_30=kidney_dynleakage_30['Pressure(bar)']
Lkidney_dynleakage_30=kidney_dynleakage_30['Laser(mm)']

# %%
# plt.figure(figsize=(9,5))
plt.plot(TO_257_dynleakage_30[::4],PO_257_dynleakage_30.rolling(window=10).mean()[::4],'tab:blue', alpha=0.15, linestyle='dotted',linewidth=3)   
plt.plot(TX_257_dynleakage_30[::4],PX_257_dynleakage_30.rolling(window=10).mean()[::4],'tab:brown', alpha=0.15, linestyle=(0,(5,2,2)))
plt.plot(TO_dynleakage_30[::4],PO_dynleakage_30.rolling(window=10).mean()[::4],'tab:blue',label='O-ring', linestyle='dotted',linewidth=3)
plt.plot(TNAPN_dynleakage_30[::4],PNAPN_dynleakage_30.rolling(window=10).mean()[::4],'tab:orange',label='NAPN',linestyle='dashdot')
plt.plot(TNAP310_dynleakage_30[::4],PNAP310_dynleakage_30.rolling(window=10).mean()[::4],'tab:green',label='NAP 310', linestyle=(0,(5,2,2)))
plt.plot(TPK_dynleakage_30[::4],PPK_dynleakage_30.rolling(window=10).mean()[::4],'tab:red',label='PK',linestyle='dashed')
plt.plot(TKDN_dynleakage_30[::4],PKDN_dynleakage_30.rolling(window=10).mean()[::4],'tab:purple',label='KDN')

plt.xlabel('Time (s)')
plt.ylabel('Pressure(bar)')
# plt.title('Dynamic leakage - Pressure drop at specific point in the cylinder')
plt.legend()
plt.savefig('test_2_dynamic_leakage_25mm.pdf',bbox_inches = 'tight')

# %%
# plt.figure(figsize=(9,5))

plt.plot(TO_dynleakage_30[::4],PO_dynleakage_30.rolling(window=10).mean()[::4],'tab:blue', alpha=0.15, linestyle='dotted',linewidth=3)
plt.plot(TNAPN_dynleakage_30[::4],PNAPN_dynleakage_30.rolling(window=10).mean()[::4],'tab:orange',alpha=0.15,linestyle='dashdot')
plt.plot(TNAP310_dynleakage_30[::4],PNAP310_dynleakage_30.rolling(window=10).mean()[::4],'tab:green',alpha=0.15, linestyle=(0,(5,2,2)))
plt.plot(TPK_dynleakage_30[::4],PPK_dynleakage_30.rolling(window=10).mean()[::4],'tab:red',alpha=0.15,linestyle='dashed')
plt.plot(TKDN_dynleakage_30[::4],PKDN_dynleakage_30.rolling(window=10).mean()[::4],'tab:purple',alpha=0.15)
plt.plot(TO_257_dynleakage_30[::4],PO_257_dynleakage_30.rolling(window=10).mean()[::4],'tab:blue',label='O-ring', linestyle='dotted',linewidth=3)  
plt.plot(TX_257_dynleakage_30[::4],PX_257_dynleakage_30.rolling(window=10).mean()[::4],'tab:brown',label='X-ring', linestyle=(0,(5,2,2)))
plt.xlabel('Time (s)')
plt.ylabel('Pressure(bar)')
# plt.title('Dynamic leakage - Pressure drop at specific point in the cylinder')
plt.legend()
plt.savefig('test_2_dynamic_leakage_257mm.pdf',bbox_inches = 'tight')

# %%
plt.plot(TO_dynleakage_30,PO_dynleakage_30.rolling(window=10).mean(),'0.8',label='Cylindrical shape', linestyle='dotted',linewidth=3)   
# plt.plot(TO_257_dynleakage_30,PO_257_dynleakage_30.rolling(window=10).mean(),'0.9',label='O-ring 25.7mm')
plt.plot(Tovaal_dynleakage_30,Povaal_dynleakage_30.rolling(window=10).mean(),'tab:olive',label='Oval shape',linestyle='dashdot')   
plt.plot(Tkidney_dynleakage_30,Pkidney_dynleakage_30.rolling(window=10).mean(),'tab:cyan',label='Curved shape')

plt.xlabel('Time (s)')
plt.ylabel('Pressure(bar)')
# plt.title('Dynamic leakage - Pressure drop at specific point in the cylinder')
plt.legend()
plt.savefig('test_2_dynamic_leakage_shapes.pdf',bbox_inches = 'tight')

# %%
Povaal_dynleakage_30
# Out:
# 299       7.547
# 320       7.189
# 1588      7.520
# 2254      7.146
# 3521      7.484
#           ...
# 120124    5.987
# 120733    6.022
# 121342    6.031
# 121985    5.672
# 123776    5.978
# Name: Pressure(bar), Length: 151, dtype: float64

# %% [markdown]
# #### Static leakage

# %%
plt.plot(TO_statleakage.head(128000).rolling(window=100).mean()[::1000],PO_statleakage.head(128000).rolling(window=100).mean()[::1000],'tab:blue',label='O-ring',linestyle='dotted',linewidth=3)    
plt.plot(TNAPN_statleakage.rolling(window=100).mean()[::1000],PNAPN_statleakage.rolling(window=100).mean()[::1000],'tab:orange',label='NAPN',linestyle='dashdot')
plt.plot(TNAP310_statleakage.rolling(window=100).mean()[::1000],PNAP310_statleakage.rolling(window=100).mean()[::1000],'tab:green',label='NAP310', linestyle=(0,(5,2,2)))
plt.plot(TPK_statleakage.head(130000).rolling(window=100).mean()[::1000],PPK_statleakage.head(130000).rolling(window=100).mean()[::1000],'tab:red',label='PK',linestyle='dashed')
plt.plot(TKDN_statleakage.rolling(window=100).mean()[::1000],PKDN_statleakage.rolling(window=100).mean()[::1000],'tab:purple',label='KDN')

# plt.plot(Tovaal_statleakage,Povaal_statleakage,'tab:olive',label='Oval shape')
# plt.plot(Tkidney_statleakage,Pkidney_statleakage,'tab:cyan',label='Kidney shape')

plt.xlabel('Time (s)')
plt.ylabel('Pressure(bar)')
plt.legend()
plt.savefig('test_2_static_leakage.pdf',bbox_inches = 'tight')

# %%
O_statleakage_pressuredrop = PO_statleakage-5.54
NAPN_statleakage_pressuredrop = PNAPN_statleakage-5.66
PK_statleakage_pressuredrop = PPK_statleakage - 5.48
KDN_statleakage_pressuredrop = PKDN_statleakage - 5.41

O_257_statleakage_pressuredrop = PO_257_statleakage-5.46
X_257_statleakage_pressuredrop = PX_257_statleakage-5.42

plt.plot(TO_257_statleakage.rolling(window=100).mean()[::1000],O_257_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:blue',alpha=0.15, linestyle='dotted',linewidth=3)
plt.plot(TX_257_statleakage.rolling(window=100).mean()[::1000],X_257_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:brown',alpha=0.15, linestyle=(0,(5,2,2)))
plt.plot(TO_statleakage.head(128000).rolling(window=100).mean()[::1000],O_statleakage_pressuredrop.head(128000).rolling(window=100).mean()[::1000],'tab:blue',label='O-ring',linestyle='dotted',linewidth=3)   
plt.plot(TNAPN_statleakage.rolling(window=100).mean()[::1000],NAPN_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:orange',label='NAPN',linestyle='dashdot')
plt.plot(TPK_statleakage.head(130000).rolling(window=100).mean()[::1000],PK_statleakage_pressuredrop.head(130000).rolling(window=100).mean()[::1000],'tab:red',label='PK',linestyle='dashed')
plt.plot(TKDN_statleakage.rolling(window=100).mean()[::1000],KDN_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:purple',label='KDN')
plt.xlabel('Time (s)')
plt.ylabel('Pressure (bar)')
plt.legend()
plt.savefig('test_2_static_leakage_part.pdf',bbox_inches = 'tight')

# %%
plt.plot(TO_statleakage.rolling(window=100).mean()[::1000],O_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:blue',alpha=0.15, linestyle='dotted',linewidth=3)
plt.plot(TNAPN_statleakage.rolling(window=100).mean()[::1000],NAPN_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:orange',alpha=0.15,linestyle='dashdot')
plt.plot(TPK_statleakage.head(130000).rolling(window=100).mean()[::1000],PK_statleakage_pressuredrop.head(130000).rolling(window=100).mean()[::1000],'tab:red',alpha=0.15,linestyle='dashed')  
plt.plot(TKDN_statleakage.rolling(window=100).mean()[::1000],KDN_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:purple',alpha=0.15)
plt.plot(TO_257_statleakage.rolling(window=100).mean()[::1000],O_257_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:blue',label='O-ring',linestyle='dotted',linewidth=3)
plt.plot(TX_257_statleakage.rolling(window=100).mean()[::1000],X_257_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:brown',label='X-ring',linestyle=(0,(5,2,2)))

plt.xlabel('Time (s)')
plt.ylabel('Pressure drop(bar)')
plt.legend(loc=3)
plt.savefig('test_2_static_leakage_257.pdf',bbox_inches = 'tight')

# %%
ovaal_statleakage_pressuredrop = Povaal_statleakage-5.65
kidney_statleakage_pressuredrop = Pkidney_statleakage-5.43

plt.plot(TO_statleakage.rolling(window=100).mean()[::1000],O_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'0.8',label='Cylindrical shape', linestyle='dotted',linewidth=3)  
plt.plot(Tovaal_statleakage.rolling(window=100).mean()[::1000],ovaal_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:olive',label='Oval shape',linestyle='dashdot')
plt.plot(Tkidney_statleakage.rolling(window=100).mean()[::1000],kidney_statleakage_pressuredrop.rolling(window=100).mean()[::1000],'tab:cyan',label='Curved shape')


plt.xlabel('Time (s)')
plt.ylabel('Pressure drop(bar)')
plt.legend()
plt.savefig('test_2_static_leakage_shapes.pdf',bbox_inches = 'tight')

# %% [markdown]
# # Test 3: Friction test

# %% [markdown]
# ### Friction force

# %%
# 1 bar
Ft_O_1bar=PO_1bar*10**5*Area
FF_O_1bar = FO_1bar - Ft_O_1bar
x_O_1bar = np.arange(0,len(LO_1bar)/100,0.01)
Ft_NAPN_1bar=PNAPN_1bar*10**5*Area
FF_NAPN_1bar = FNAPN_1bar - Ft_NAPN_1bar
x_NAPN_1bar = np.arange(0,len(LNAPN_1bar)/100,0.01)
Ft_NAP310_1bar=PNAP310_1bar*10**5*Area
FF_NAP310_1bar = FNAP310_1bar - Ft_NAP310_1bar
x_NAP310_1bar = np.arange(0,len(LNAP310_1bar)/100,0.01)
Ft_PK_1bar=PPK_1bar*10**5*Area
FF_PK_1bar = FPK_1bar - Ft_PK_1bar
x_PK_1bar = np.arange(0,len(LPK_1bar)/100,0.01)
Ft_KDN_1bar=PKDN_1bar*10**5*Area
FF_KDN_1bar = FKDN_1bar - Ft_KDN_1bar
x_KDN_1bar = np.arange(0,len(LKDN_1bar)/100,0.01)

Ft_O_257_1bar=PO_257_1bar*10**5*Areagroot
FF_O_257_1bar = FO_257_1bar - Ft_O_257_1bar
x_O_257_1bar = np.arange(0,len(LO_257_1bar)/100,0.01)
Ft_X_257_1bar=PX_257_1bar*10**5*Areagroot
FF_X_257_1bar = FX_257_1bar - Ft_X_257_1bar
x_X_257_1bar = np.arange(0,len(LX_257_1bar)/100,0.01)

# 3 bar
Ft_O_3bar=PO_3bar*10**5*Area
FF_O_3bar = FO_3bar - Ft_O_3bar
x_O_3bar = np.arange(0,len(LO_3bar)/100,0.01)
Ft_NAPN_3bar=PNAPN_3bar*10**5*Area
FF_NAPN_3bar = FNAPN_3bar - Ft_NAPN_3bar
x_NAPN_3bar = np.arange(0,len(LNAPN_3bar)/100,0.01)
Ft_NAP310_3bar=PNAP310_3bar*10**5*Area
FF_NAP310_3bar = FNAP310_3bar - Ft_NAP310_3bar
x_NAP310_3bar = np.arange(0,len(LNAP310_3bar)/100,0.01)
Ft_PK_3bar=PPK_3bar*10**5*Area
FF_PK_3bar = FPK_3bar - Ft_PK_3bar
x_PK_3bar = np.arange(0,len(LPK_3bar)/100,0.01)
Ft_KDN_3bar=PKDN_3bar*10**5*Area
FF_KDN_3bar = FKDN_3bar - Ft_KDN_3bar
x_KDN_3bar = np.arange(0,len(LKDN_3bar)/100,0.01)

Ft_O_257_3bar=PO_257_3bar*10**5*Areagroot
FF_O_257_3bar = FO_257_3bar - Ft_O_257_3bar
x_O_257_3bar = np.arange(0,len(LO_257_3bar)/100,0.01)
Ft_X_257_3bar=PX_257_3bar*10**5*Areagroot
FF_X_257_3bar = FX_257_3bar - Ft_X_257_3bar
x_X_257_3bar = np.arange(0,len(LX_257_3bar)/100,0.01)

# 5 bar
Ft_O_5bar=PO_5bar*10**5*Area
FF_O_5bar = FO_5bar - Ft_O_5bar
x_O_5bar = np.arange(0,len(LO_5bar)/100,0.01)
Ft_NAPN_5bar=PNAPN_5bar*10**5*Area
FF_NAPN_5bar = FNAPN_5bar - Ft_NAPN_5bar
x_NAPN_5bar = np.arange(0,len(LNAPN_5bar)/100,0.01)
Ft_NAP310_5bar=PNAP310_5bar*10**5*Area
FF_NAP310_5bar = FNAP310_5bar - Ft_NAP310_5bar
x_NAP310_5bar = np.arange(0,len(LNAP310_5bar)/100,0.01)
Ft_PK_5bar=PPK_5bar*10**5*Area
FF_PK_5bar = FPK_5bar - Ft_PK_5bar
x_PK_5bar = np.arange(0,len(LPK_5bar)/100,0.01)
Ft_KDN_5bar=PKDN_5bar*10**5*Area
FF_KDN_5bar = FKDN_5bar - Ft_KDN_5bar
x_KDN_5bar = np.arange(0,len(LKDN_5bar)/100,0.01)

Ft_O_257_5bar=PO_257_5bar*10**5*Areagroot
FF_O_257_5bar = FO_257_5bar - Ft_O_257_5bar
x_O_257_5bar = np.arange(0,len(LO_257_5bar)/100,0.01)
Ft_X_257_5bar=PX_257_5bar*10**5*Areagroot
FF_X_257_5bar = FX_257_5bar - Ft_X_257_5bar
x_X_257_5bar = np.arange(0,len(LX_257_5bar)/100,0.01)

# 7 bar
Ft_O_7bar=PO_7bar*10**5*Area
FF_O_7bar = FO_7bar - Ft_O_7bar
x_O_7bar = np.arange(0,len(LO_7bar)/100,0.01)
Ft_NAPN_7bar=PNAPN_7bar*10**5*Area
FF_NAPN_7bar = FNAPN_7bar - Ft_NAPN_7bar
x_NAPN_7bar = np.arange(0,len(LNAPN_7bar)/100,0.01)
Ft_NAP310_7bar=PNAP310_7bar*10**5*Area
FF_NAP310_7bar = FNAP310_7bar - Ft_NAP310_7bar
x_NAP310_7bar = np.arange(0,len(LNAP310_7bar)/100,0.01)
Ft_PK_7bar=PPK_7bar*10**5*Area
FF_PK_7bar = FPK_7bar - Ft_PK_7bar
x_PK_7bar = np.arange(0,len(LPK_7bar)/100,0.01)
Ft_KDN_7bar=PKDN_7bar*10**5*Area
FF_KDN_7bar = FKDN_7bar - Ft_KDN_7bar
x_KDN_7bar = np.arange(0,len(LKDN_7bar)/100,0.01)

Ft_O_257_7bar=PO_257_7bar*10**5*Areagroot
FF_O_257_7bar = FO_257_7bar - Ft_O_257_7bar
x_O_257_7bar = np.arange(0,len(LO_257_7bar)/100,0.01)
Ft_X_257_7bar=PX_257_7bar*10**5*Areagroot
FF_X_257_7bar = FX_257_7bar - Ft_X_257_7bar
x_X_257_7bar = np.arange(0,len(LX_257_7bar)/100,0.01)

# %%
plt.plot(x_O_1bar,FF_O_1bar,'tab:blue',label='O-ring')
plt.plot(x_NAPN_1bar,FF_NAPN_1bar,'tab:orange',label='NAPN')
plt.plot(x_NAP310_1bar,FF_NAP310_1bar,'tab:green',label='NAP 310')
plt.plot(x_PK_1bar,FF_PK_1bar,'tab:red',label='PK')
plt.plot(x_KDN_1bar,FF_KDN_1bar,'tab:purple',label='KDN')


plt.xlabel('Time (s)')
plt.ylabel('Force (N)')
# plt.title('Friction force at ±1 bar')
plt.legend(loc='lower center',bbox_to_anchor=(0.5,-0.3),ncol=5)

plt.savefig('frictionforce_1bar.pdf',bbox_inches = 'tight')

# %%
# plt.plot(x_O_7bar,FF_O_7bar,'0.8',label='O-ring')
# plt.plot(x_NAPN_7bar,FF_NAPN_7bar,'0.8',label='NAPN')
# plt.plot(x_NAP310_7bar,FF_NAP310_7bar,'0.8',label='NAP 310')
# plt.plot(x_PK_7bar,FF_PK_7bar,'0.8',label='PK')
# plt.plot(x_KDN_7bar,FF_KDN_7bar,'0.8',label='KDN')
# plt.plot(x_O_257_7bar,FF_O_257_7bar,'tab:blue',label='O-ring')
# plt.plot(x_X_257_7bar,FF_X_257_7bar,'tab:brown',label='X-ring')


# plt.xlabel('Time (s)')
# plt.ylabel('Force (N)')
# plt.title('Friction force at ±1 bar')
# plt.legend()

# plt.savefig('frictionforce_7bar.pdf',bbox_inches = 'tight')

# %%
plt.plot(x_O_3bar,FF_O_3bar,'tab:blue',label='O-ring')
plt.plot(x_NAPN_3bar,FF_NAPN_3bar,'tab:orange',label='NAPN')
plt.plot(x_NAP310_3bar,FF_NAP310_3bar,'tab:green',label='NAP 310')
plt.plot(x_PK_3bar,FF_PK_3bar,'tab:red',label='PK')
plt.plot(x_KDN_3bar,FF_KDN_3bar,'tab:purple',label='KDN')


plt.xlabel('Time (s)')
plt.ylabel('Force (N)')
# plt.title('Friction force at ±3 bar')
plt.legend(loc='lower center',bbox_to_anchor=(0.5,-0.3),ncol=5)

plt.savefig('frictionforce_3bar.pdf',bbox_inches = 'tight')

# %%
plt.plot(x_O_5bar,FF_O_5bar,'tab:blue',label='O-ring')
plt.plot(x_NAPN_5bar,FF_NAPN_5bar,'tab:orange',label='NAPN')
plt.plot(x_NAP310_5bar,FF_NAP310_5bar,'tab:green',label='NAP 310')
plt.plot(x_PK_5bar,FF_PK_5bar,'tab:red',label='PK')
plt.plot(x_KDN_5bar,FF_KDN_5bar,'tab:purple',label='KDN')


plt.xlabel('Time (s)')
plt.ylabel('Force (N)')
# plt.title('Friction force at ±5 bar')
plt.legend(loc='lower center',bbox_to_anchor=(0.5,-0.3),ncol=5)

plt.savefig('frictionforce_5bar.pdf',bbox_inches = 'tight')

# %%
plt.plot(x_O_7bar,FF_O_7bar,'tab:blue',label='O-ring')
plt.plot(x_NAPN_7bar,FF_NAPN_7bar,'tab:orange',label='NAPN')
plt.plot(x_NAP310_7bar,FF_NAP310_7bar,'tab:green',label='NAP 310')
plt.plot(x_PK_7bar,FF_PK_7bar,'tab:red',label='PK')
plt.plot(x_KDN_7bar,FF_KDN_7bar,'tab:purple',label='KDN')


plt.xlabel('Time (s)')
plt.ylabel('Force (N)')
# plt.title('Friction force at ±7 bar')
plt.legend(loc='lower center',bbox_to_anchor=(0.5,-0.3),ncol=5)

plt.savefig('frictionforce_7bar.pdf',bbox_inches = 'tight')

# %%
frictieheenweg_O_1 = FF_O_1bar[FF_O_1bar>0].mean()
frictieheenweg_NAPN_1 = FF_NAPN_1bar[FF_NAPN_1bar>0].mean()
frictieheenweg_NAP310_1 = FF_NAP310_1bar[FF_NAP310_1bar>0].mean()
frictieheenweg_PK_1 = FF_PK_1bar[FF_PK_1bar>0].mean()
frictieheenweg_KDN_1 = FF_KDN_1bar[FF_KDN_1bar>0].mean()

frictieheenweg_O_3 = FF_O_3bar[FF_O_3bar>0].mean()
frictieheenweg_NAPN_3 = FF_NAPN_3bar[FF_NAPN_3bar>0].mean()
frictieheenweg_NAP310_3 = FF_NAP310_3bar[FF_NAP310_3bar>0].mean()
frictieheenweg_PK_3 = FF_PK_3bar[FF_PK_3bar>0].mean()
frictieheenweg_KDN_3 = FF_KDN_3bar[FF_KDN_3bar>0].mean()

frictieheenweg_O_5 = FF_O_5bar[FF_O_5bar>0].mean()
frictieheenweg_NAPN_5 = FF_NAPN_5bar[FF_NAPN_5bar>0].mean()
frictieheenweg_NAP310_5 = FF_NAP310_5bar[FF_NAP310_5bar>0].mean()
frictieheenweg_PK_5 = FF_PK_5bar[FF_PK_5bar>0].mean()
frictieheenweg_KDN_5 = FF_KDN_5bar[FF_KDN_5bar>0].mean()

frictieheenweg_O_7 = FF_O_7bar[FF_O_7bar>0].mean()
frictieheenweg_NAPN_7 = FF_NAPN_7bar[FF_NAPN_7bar>0].mean()
frictieheenweg_NAP310_7 = FF_NAP310_7bar[FF_NAP310_7bar>0].mean()
frictieheenweg_PK_7 = FF_PK_7bar[FF_PK_7bar>0].mean()
frictieheenweg_KDN_7 = FF_KDN_7bar[FF_KDN_7bar>0].mean()

frictieterugweg_O_1 = FF_O_1bar[FF_O_1bar<0].mean()
frictieterugweg_NAPN_1 = FF_NAPN_1bar[FF_NAPN_1bar<0].mean()
frictieterugweg_NAP310_1 = FF_NAP310_1bar[FF_NAP310_1bar<0].mean()
frictieterugweg_PK_1 = FF_PK_1bar[FF_PK_1bar<0].mean()
frictieterugweg_KDN_1 = FF_KDN_1bar[FF_KDN_1bar<0].mean()

frictieterugweg_O_3 = FF_O_3bar[FF_O_3bar<0].mean()
frictieterugweg_NAPN_3 = FF_NAPN_3bar[FF_NAPN_3bar<0].mean()
frictieterugweg_NAP310_3 = FF_NAP310_3bar[FF_NAP310_3bar<0].mean()
frictieterugweg_PK_3 = FF_PK_3bar[FF_PK_3bar<0].mean()
frictieterugweg_KDN_3 = FF_KDN_3bar[FF_KDN_3bar<0].mean()

frictieterugweg_O_5 = FF_O_5bar[FF_O_5bar<0].mean()
frictieterugweg_NAPN_5 = FF_NAPN_5bar[FF_NAPN_5bar<0].mean()
frictieterugweg_NAP310_5 = FF_NAP310_5bar[FF_NAP310_5bar<0].mean()
frictieterugweg_PK_5 = FF_PK_5bar[FF_PK_5bar<0].mean()
frictieterugweg_KDN_5 = FF_KDN_5bar[FF_KDN_5bar<0].mean()

frictieterugweg_O_7 = FF_O_7bar[FF_O_7bar<0].mean()
frictieterugweg_NAPN_7 = FF_NAPN_7bar[FF_NAPN_7bar<0].mean()
frictieterugweg_NAP310_7 = FF_NAP310_7bar[FF_NAP310_7bar<0].mean()
frictieterugweg_PK_7 = FF_PK_7bar[FF_PK_7bar<0].mean()
frictieterugweg_KDN_7 = FF_KDN_7bar[FF_KDN_7bar<0].mean()

# %%
frictieheenweg_O_257_1 = FF_O_257_1bar[FF_O_257_1bar>0].mean()
frictieheenweg_O_257_3 = FF_O_257_3bar[FF_O_257_3bar>0].mean()
frictieheenweg_O_257_5 = FF_O_257_5bar[FF_O_257_5bar>0].mean()
frictieheenweg_O_257_7 = FF_O_257_7bar[FF_O_257_7bar>0].mean()
frictieterugweg_O_257_1 = FF_O_257_1bar[FF_O_257_1bar<0].mean()
frictieterugweg_O_257_3 = FF_O_257_3bar[FF_O_257_3bar<0].mean()
frictieterugweg_O_257_5 = FF_O_257_5bar[FF_O_257_5bar<0].mean()
frictieterugweg_O_257_7 = FF_O_257_7bar[FF_O_257_7bar<0].mean()

frictieheenweg_X_257_1 = FF_X_257_1bar[FF_X_257_1bar>0].mean()
frictieheenweg_X_257_3 = FF_X_257_3bar[FF_X_257_3bar>0].mean()
frictieheenweg_X_257_5 = FF_X_257_5bar[FF_X_257_5bar>0].mean()
frictieheenweg_X_257_7 = FF_X_257_7bar[FF_X_257_7bar>0].mean()
frictieterugweg_X_257_1 = FF_X_257_1bar[FF_X_257_1bar<0].mean()
frictieterugweg_X_257_3 = FF_X_257_3bar[FF_X_257_3bar<0].mean()
frictieterugweg_X_257_5 = FF_X_257_5bar[FF_X_257_5bar<0].mean()
frictieterugweg_X_257_7 = FF_X_257_7bar[FF_X_257_7bar<0].mean()

# %%
plt.annotate(text='',xy=(12,frictieheenweg_O_1), xytext=(12,frictieterugweg_O_1), arrowprops=dict(arrowstyle='<->', lw=2))
plt.hlines(xmin=0, xmax=70,y=frictieheenweg_O_1, linestyles='dashed', colors='0', lw=2)
plt.hlines(xmin=0, xmax=70,y=frictieterugweg_O_1, linestyles='dashed', colors='0', lw=2)
plt.plot(x_O_1bar,FF_O_1bar,'tab:blue',label='O-ring')
plt.plot(x_NAPN_1bar,FF_NAPN_1bar,'tab:orange',alpha=0.2,label='NAPN')
plt.plot(x_NAP310_1bar,FF_NAP310_1bar,'tab:green',alpha=0.2,label='NAP 330')
plt.plot(x_PK_1bar,FF_PK_1bar,'tab:red',alpha=0.2,label='PK')
plt.plot(x_KDN_1bar,FF_KDN_1bar,'tab:purple', alpha=0.2,label='KDN')


plt.xlim([5,15])
plt.xlabel('Time (s)')
plt.ylabel('Force (N)')
# plt.title('Friction force at ±5 bar')
plt.legend(loc='lower center',bbox_to_anchor=(0.5,-0.3),ncol=5)

plt.savefig('frictionforce_1bar_zoom.pdf',bbox_inches = 'tight')

# %%
# d = {'Pressure': [1,3,5,7],
#      'Oring': [frictieheenweg_O_1,frictieheenweg_O_3,frictieheenweg_O_5,frictieheenweg_O_7],
#      'NAPN':[frictieheenweg_NAPN_1,frictieheenweg_NAPN_3,frictieheenweg_NAPN_5,frictieheenweg_NAPN_7],
#      'NAP310':[frictieheenweg_NAP310_1,frictieheenweg_NAP310_3,frictieheenweg_NAP310_5,frictieheenweg_NAP310_7],
#      'PK': [frictieheenweg_PK_1,frictieheenweg_PK_3,frictieheenweg_PK_5,frictieheenweg_PK_7],
#      'KDN': [frictieheenweg_KDN_1,frictieheenweg_KDN_3,frictieheenweg_KDN_5,frictieheenweg_KDN_7],
#     }
# frictie_pressure = pd.DataFrame(data=d)
# plt.plot(frictie_pressure.Pressure,frictie_pressure.Oring,'tab:blue',label='O-ring')
# plt.plot(frictie_pressure.Pressure,frictie_pressure.NAPN,'tab:orange',label='NAPN')
# plt.plot(frictie_pressure.Pressure,frictie_pressure.NAP310,'tab:green',label='NAP310')
# plt.plot(frictie_pressure.Pressure,frictie_pressure.PK,'tab:red',label='PK')
# plt.plot(frictie_pressure.Pressure,frictie_pressure.KDN,'tab:purple',label='KDN')
# plt.xlabel('Pressure (bar)')
# plt.ylabel('Dynamic friction force (N)')
# # plt.title('Dynamic friction force on retracting stroke')
# plt.legend()

# %%
# t = {'Pressure': [1,3,5,7],
#      'Oring': [frictieterugweg_O_1,frictieterugweg_O_3,frictieterugweg_O_5,frictieterugweg_O_7],
#      'NAPN':[frictieterugweg_NAPN_1,frictieterugweg_NAPN_3,frictieterugweg_NAPN_5,frictieterugweg_NAPN_7],
#      'NAP310':[frictieterugweg_NAP310_1,frictieterugweg_NAP310_3,frictieterugweg_NAP310_5,frictieterugweg_NAP310_7],
#      'PK': [frictieterugweg_PK_1,frictieterugweg_PK_3,frictieterugweg_PK_5,frictieterugweg_PK_7],
#      'KDN': [frictieterugweg_KDN_1,frictieterugweg_KDN_3,frictieterugweg_KDN_5,frictieterugweg_KDN_7],
#     }
# frictie_pressure_terugweg = pd.DataFrame(data=t)
# plt.plot(frictie_pressure_terugweg.Pressure,frictie_pressure_terugweg.Oring,'tab:blue',label='O-ring')
# plt.plot(frictie_pressure_terugweg.Pressure,frictie_pressure_terugweg.NAPN,'tab:orange',label='NAPN')
# plt.plot(frictie_pressure_terugweg.Pressure,frictie_pressure_terugweg.NAP310,'tab:green',label='NAP310')
# plt.plot(frictie_pressure_terugweg.Pressure,frictie_pressure_terugweg.PK,'tab:red',label='PK')
# plt.plot(frictie_pressure_terugweg.Pressure,frictie_pressure_terugweg.KDN,'tab:purple',label='KDN')
# plt.xlabel('Pressure (bar)')
# plt.ylabel('Dynamic friction force (N)')
# plt.title('Dynamic friction force on retracting stroke')
# plt.legend()

# %% [markdown]
# #### Amplitude frictie

# %%
frictierange_O_1 = frictieheenweg_O_1 - frictieterugweg_O_1
frictierange_NAPN_1 = frictieheenweg_NAPN_1 - frictieterugweg_NAPN_1
frictierange_NAP310_1 = frictieheenweg_NAP310_1 - frictieterugweg_NAP310_1
frictierange_PK_1 = frictieheenweg_PK_1 - frictieterugweg_PK_1
frictierange_KDN_1 = frictieheenweg_KDN_1 - frictieterugweg_KDN_1
#TEST O-RING 2 BAR NOG UITVOEREN!
frictierange_O_2=np.sum(frictierange_O_3+frictierange_O_1)/2

frictierange_O_3 = frictieheenweg_O_3 - frictieterugweg_O_3
frictierange_NAPN_3 = frictieheenweg_NAPN_3 - frictieterugweg_NAPN_3
frictierange_NAP310_3 = frictieheenweg_NAP310_3 - frictieterugweg_NAP310_3
frictierange_PK_3 = frictieheenweg_PK_3 - frictieterugweg_PK_3
frictierange_KDN_3 = frictieheenweg_KDN_3 - frictieterugweg_KDN_3

frictierange_O_5 = frictieheenweg_O_5 - frictieterugweg_O_5
frictierange_NAPN_5 = frictieheenweg_NAPN_5 - frictieterugweg_NAPN_5
frictierange_NAP310_5 = frictieheenweg_NAP310_5 - frictieterugweg_NAP310_5
frictierange_PK_5 = frictieheenweg_PK_5 - frictieterugweg_PK_5
frictierange_KDN_5 = frictieheenweg_KDN_5 - frictieterugweg_KDN_5

frictierange_O_7 = frictieheenweg_O_7 - frictieterugweg_O_7
frictierange_NAPN_7 = frictieheenweg_NAPN_7 - frictieterugweg_NAPN_7
frictierange_NAP310_7 = frictieheenweg_NAP310_7 - frictieterugweg_NAP310_7
frictierange_PK_7 = frictieheenweg_PK_7 - frictieterugweg_PK_7
frictierange_KDN_7 = frictieheenweg_KDN_7 - frictieterugweg_KDN_7

# %%
frictierange_O_257_1 = frictieheenweg_O_257_1 - frictieterugweg_O_257_1
frictierange_O_257_3 = frictieheenweg_O_257_3 - frictieterugweg_O_257_3
frictierange_O_257_5 = frictieheenweg_O_257_5 - frictieterugweg_O_257_5
frictierange_O_257_7 = frictieheenweg_O_257_7 - frictieterugweg_O_257_7

frictierange_X_257_1 = frictieheenweg_X_257_1 - frictieterugweg_X_257_1
frictierange_X_257_3 = frictieheenweg_X_257_3 - frictieterugweg_X_257_3
frictierange_X_257_5 = frictieheenweg_X_257_5 - frictieterugweg_X_257_5
frictierange_X_257_7 = frictieheenweg_X_257_7 - frictieterugweg_X_257_7

# %%
fr = {'Pressure': [1,3,5,7],
     'Oring': [frictierange_O_1,frictierange_O_3,frictierange_O_5,frictierange_O_7],
     'NAPN':[frictierange_NAPN_1,frictierange_NAPN_3,frictierange_NAPN_5,frictierange_NAPN_7],
     'NAP310':[frictierange_NAP310_1,frictierange_NAP310_3,frictierange_NAP310_5,frictierange_NAP310_7],
     'PK': [frictierange_PK_1,frictierange_PK_3,frictierange_PK_5,frictierange_PK_7],
     'KDN': [frictierange_KDN_1,frictierange_KDN_3,frictierange_KDN_5,frictierange_KDN_7],
     'Oring_257mm': [frictierange_O_257_1,frictierange_O_257_3,frictierange_O_257_5,frictierange_O_257_7],
     'Xring_257mm': [frictierange_X_257_1,frictierange_X_257_3,frictierange_X_257_5,frictierange_X_257_7],
    }
frictie_range = pd.DataFrame(data=fr)

plt.plot(frictie_range.Pressure,frictie_range.Oring_257mm,marker='o',color='tab:blue',alpha=0.15,linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.Xring_257mm,marker='v',color='tab:brown',alpha=0.15,linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.Oring,marker='o',color='tab:blue',label='O-ring',linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.NAPN,marker='s',color='tab:orange',label='NAPN',linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.NAP310,marker='x',color='tab:green',label='NAP310',linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.PK,marker='*',color='tab:red',label='PK',linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.KDN,marker='D',color='tab:purple',label='KDN',linewidth=0.5)
plt.xlabel('Pressure (bar)')
plt.ylabel('Dynamic friction force range (N)')
# plt.title('')
plt.legend()
plt.savefig('test_3_results_frictionforcerange_25mm.pdf',bbox_inches = 'tight')

# %%
frictie_range
# Out:
#    Pressure      Oring       NAPN     NAP310         PK        KDN  \
# 0         1   7.830568   6.685799   3.802288   5.180881  11.249405
# 1         3  10.883395  13.676741   7.207355   7.057014  11.316836
# 2         5  13.915362  19.094269   9.922191  10.669887  12.294908
# 3         7  15.733489  23.284389  14.868522  12.884955  13.546720
#
#    Oring_257mm  Xring_257mm
# 0     9.165741     8.956956
# 1    11.391373    12.868667
# 2    13.657213    17.070485
# 3    15.344093    29.861896

# %%
plt.plot(frictie_range.Pressure,frictie_range.Oring,marker='o',color='tab:blue',alpha=0.15,linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.NAPN,marker='s',color='tab:orange',alpha=0.15,linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.NAP310,marker='x',color='tab:green',alpha=0.15,linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.PK,marker='*',color='tab:red',alpha=0.15,linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.KDN,marker='D',color='tab:purple',alpha=0.15,linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.Oring_257mm,marker='o',color='tab:blue',label='O-ring',linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.Xring_257mm,marker='v',color='tab:brown',label='X-ring',linewidth=0.5)
plt.xlabel('Pressure (bar)')
plt.ylabel('Dynamic friction force range (N)')
# plt.title('')
plt.legend()
plt.savefig('test_3_results_frictionforcerange_257mm.pdf',bbox_inches = 'tight')

# %% [markdown]
# # Andere shapes

# %%
fr = {'Pressure': [1,2,3],
     'Oring': [frictierange_O_1,np.sum(frictierange_O_3+frictierange_O_1)/2,frictierange_O_3],
     'oval_shape': [frictierange_ovaal_1,frictierange_ovaal_2,frictierange_ovaal_3],
     'kidney_shape': [frictierange_kidney_1,frictierange_kidney_2,frictierange_kidney_3],
    }
frictie_range = pd.DataFrame(data=fr)
plt.plot(frictie_range.Pressure,frictie_range.Oring,marker='o',color='0.8',label='Cylindrical shape',linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.oval_shape,marker='v',color='tab:olive', label='Oval shape',linewidth=0.5)
plt.plot(frictie_range.Pressure,frictie_range.kidney_shape,marker='x',color='tab:cyan', label='Curved shape',linewidth=0.5)

plt.xlabel('Pressure (bar)')
plt.ylabel('Dynamic friction force range (N)')
# plt.title('')
plt.legend(loc=2)
plt.savefig('test_3_results_frictionforcerange_shape.pdf',bbox_inches = 'tight')

# %%
frictie_range
# Out:
#    Pressure      Oring  oval_shape  kidney_shape
# 0         1   7.830568    9.352773     13.629908
# 1         2   9.356982    9.207358     21.239729
# 2         3  10.883395   10.769790     19.359670
